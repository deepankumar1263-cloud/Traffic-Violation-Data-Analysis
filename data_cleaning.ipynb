# %%
import pandas as pd

# %%
df=pd.read_csv("Traffic_Violations.csv")

# %%
df.shape
# Out:
# (2070115, 43)

# %%
df.drop_duplicates(inplace=True)

# %%
df.reset_index(drop=True)
# Out:
#                                         SeqID Date Of Stop Time Of Stop  \
# 0        52282e8c-f2e1-4bb5-8509-2d5e4f8da8ca   05/01/2023     23:11:00
# 1        b66f253b-af29-4bc4-bb73-93755ca2a779   08/31/2023     16:41:00
# 2        b66f253b-af29-4bc4-bb73-93755ca2a779   08/31/2023     16:41:00
# 3        b66f253b-af29-4bc4-bb73-93755ca2a779   08/31/2023     16:41:00
# 4        b66f253b-af29-4bc4-bb73-93755ca2a779   08/31/2023     16:41:00
# ...                                       ...          ...          ...
# 2067756  242e2d07-6bf2-4648-8c22-8b06f37ce91f   12/04/2025     13:14:00
# 2067757  0cb33bba-d1bc-424e-8c28-6943627c5845   12/04/2025     15:14:00
# 2067758  cb00a667-2837-4e57-8cff-103106fca828   12/04/2025     21:18:00
# 2067759  3c842be5-9cd1-43a0-85bd-28c835aca357   12/04/2025     07:28:00
# 2067760  047a24ba-9537-48ab-b4ce-c17386715d0f   12/04/2025     13:33:00
#
#         Agency                                        SubAgency  \
# ...

# %%
df.shape
# Out:
# (2067761, 43)

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#                                   SeqID Date Of Stop Time Of Stop Agency  \
# 0  52282e8c-f2e1-4bb5-8509-2d5e4f8da8ca   05/01/2023     23:11:00    MCP
# 1  b66f253b-af29-4bc4-bb73-93755ca2a779   08/31/2023     16:41:00    MCP
# 2  b66f253b-af29-4bc4-bb73-93755ca2a779   08/31/2023     16:41:00    MCP
# 3  b66f253b-af29-4bc4-bb73-93755ca2a779   08/31/2023     16:41:00    MCP
# 4  b66f253b-af29-4bc4-bb73-93755ca2a779   08/31/2023     16:41:00    MCP
#
#                                          SubAgency  \
# 0                      3rd District, Silver Spring
# 1  6th District, Gaithersburg / Montgomery Village
# 2  6th District, Gaithersburg / Montgomery Village
# 3  6th District, Gaithersburg / Montgomery Village
# 4  6th District, Gaithersburg / Montgomery Village
#
#                                          Description  \
# 0    OPERATING UNREGISTERED MOTOR VEHICLE ON HIGHWAY
# 1  DRIVING TO DRIVE MOTOR VEHICLE ON HIGHWAY WITH...
# ...

# %%
df.dtypes
# Out:
# SeqID                       object
# Date Of Stop                object
# Time Of Stop                object
# Agency                      object
# SubAgency                   object
# Description                 object
# Location                    object
# Latitude                   float64
# Longitude                  float64
# Accident                    object
# Belts                       object
# Personal Injury             object
# Property Damage             object
# Fatal                       object
# Commercial License          object
# HAZMAT                      object
# Commercial Vehicle          object
# Alcohol                     object
# Work Zone                   object
# Search Conducted            object
# Search Disposition          object
# Search Outcome              object
# Search Reason               object
# Search Reason For Stop      object
# Search Type                 object
# Search Arrest Reason        object
# State                       object
# ...

# %%
# Col 1
df["SeqID"]=df["SeqID"].astype("string")
df["SeqID"].dtypes
# Out:
# string[python]

# %%
# Col 2
df["Date Of Stop"].str.contains(r"\d{2}[/-]\d{2}[/-]\d{4}").sum()
# Out:
# np.int64(2067761)

# %%
# Col 2
df["Date Of Stop"]=df["Date Of Stop"].replace(r"-","/",regex=True)
df["Date Of Stop"].head()
# Out:
# 0    05/01/2023
# 1    08/31/2023
# 2    08/31/2023
# 3    08/31/2023
# 4    08/31/2023
# Name: Date Of Stop, dtype: object

# %%
# Col 2
list1=[]
list2=[]
list3=[]
for i in df["Date Of Stop"].str.split("/"):
    list1.append(i[0])
    list2.append(i[1])
    list3.append(i[2])

print(set(list1))
print(set(list2))
print(set(list3))
# Out:
# {'10', '09', '06', '07', '01', '02', '03', '05', '08', '04', '11', '12'}
# {'19', '06', '22', '03', '30', '11', '28', '17', '25', '27', '16', '10', '18', '02', '20', '08', '29', '14', '26', '07', '13', '31', '05', '04', '24', '15', '12', '09', '01', '21', '23'}
# {'2019', '2023', '2017', '2025', '2015', '2012', '2018', '2021', '2014', '2022', '2024', '2020', '2016', '2013'}

# %%
# Col 2
df["Date Of Stop"] = pd.to_datetime(df["Date Of Stop"],format="%m/%d/%Y")

# %%
df["Time Of Stop"].head()
# Out:
# 0    23:11:00
# 1    16:41:00
# 2    16:41:00
# 3    16:41:00
# 4    16:41:00
# Name: Time Of Stop, dtype: object

# %%
# Col 3
df["Time Of Stop"].str.contains(r"\b\d{2}:\d{2}:\d{2}\b").sum()
# Out:
# np.int64(2067761)

# %%
# Col 3
list1=[]
list2=[]
list3=[]

for i in df["Time Of Stop"].str.split(":"):
    list1.append(i[0])
    list2.append(i[1])
    list3.append(i[2])

print(set(list1))
print(set(list2))
print(set(list3))
# Out:
# {'19', '06', '22', '03', '11', '17', '16', '00', '10', '18', '02', '20', '08', '14', '07', '13', '04', '05', '15', '12', '09', '01', '21', '23'}
# {'32', '19', '06', '22', '03', '39', '11', '30', '28', '25', '27', '17', '53', '16', '43', '50', '40', '00', '10', '18', '34', '02', '47', '20', '08', '29', '35', '46', '14', '54', '48', '55', '26', '07', '13', '31', '05', '04', '24', '15', '49', '12', '33', '57', '58', '38', '45', '09', '36', '41', '44', '51', '01', '37', '56', '52', '21', '23', '59', '42'}
# {'00'}

# %%
# Col 3
df["Time Of Stop"]=pd.to_datetime(df["Time Of Stop"],format="%H:%M:%S").dt.time

# %%
# Col 3
df["Time Of Stop"].dtypes
# Out:
# dtype('O')

# %%
# Col 4
df["Agency"].unique()
# Out:
# array(['MCP'], dtype=object)

# %%
# Col 4
df["Agency"]=df["Agency"].astype("string")

# %%
# Col 5
df["District Number"]=df["SubAgency"].str.extract(r"(^\d+)")

# %%
# Col 5
df["SubAgency"]=df["SubAgency"].astype("string")
df["SubAgency"].dtypes
# Out:
# string[python]

# %%
# Col 6
df["Description"]=df["Description"].str.lower()

# %%
# Col 6
df["Description"]=df["Description"].astype("string")
df["Description"].dtypes
# Out:
# string[python]

# %%
# Col 7
df["Location"]=df["Location"].replace(r"\s*[@/]+\s*","/",regex=True).str.lower().str.strip()

# %%
# Col 7
df["Location"]=df["Location"].fillna("Not Applicable")

# %%
# Col 7
df["Location"].isna().sum()
# Out:
# np.int64(0)

# %%
# Col 7
df[df["Location"].str.contains(r"([rR]+[dD]+|[rR]+[oO]+[aA]+[dD]+)")]["Location"]
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_11384\1008620270.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df[df["Location"].str.contains(r"([rR]+[dD]+|[rR]+[oO]+[aA]+[dD]+)")]["Location"]
# 0             briggs chaney rd/columiba pike
# 5                 kemp mill road/alpert lane
# 15            jones mill road/le velle drive
# 16            jones mill road/le velle drive
# 17            jones mill road/le velle drive
#                          ...
# 2070103          watkins mill rd/spectrum dr
# 2070106         germantown rd/dawson farm rd
# 2070108      east west highway/colesville rd
# 2070112    e randolph road/old columbia pike
# 2070113          gainsborough rd/hob nail ct
# Name: Location, Length: 994387, dtype: object

# %%
df[["Latitude","Longitude"]].dtypes
# Out:
# Latitude     float64
# Longitude    float64
# dtype: object

# %%
# Col 8 and 9
import numpy as np
df["Latitude"]=df["Latitude"].replace(0.0,np.nan)
df["Longitude"]=df["Longitude"].replace(0.0,np.nan)

# %%
# Col 8 and 9
df[(df["Latitude"]>90) | (df["Latitude"]<-90)]
# Out:
# Empty DataFrame
# Columns: [SeqID, Date Of Stop, Time Of Stop, Agency, SubAgency, Description, Location, Latitude, Longitude, Accident, Belts, Personal Injury, Property Damage, Fatal, Commercial License, HAZMAT, Commercial Vehicle, Alcohol, Work Zone, Search Conducted, Search Disposition, Search Outcome, Search Reason, Search Reason For Stop, Search Type, Search Arrest Reason, State, VehicleType, Year, Make, Model, Color, Violation Type, Charge, Article, Contributed To Accident, Race, Gender, Driver City, Driver State, DL State, Arrest Type, Geolocation, District Number]
# Index: []

# %%
# Col 8 and 9
df[(df["Longitude"]>180)|(df["Longitude"]<-180)]
# Out:
# Empty DataFrame
# Columns: [SeqID, Date Of Stop, Time Of Stop, Agency, SubAgency, Description, Location, Latitude, Longitude, Accident, Belts, Personal Injury, Property Damage, Fatal, Commercial License, HAZMAT, Commercial Vehicle, Alcohol, Work Zone, Search Conducted, Search Disposition, Search Outcome, Search Reason, Search Reason For Stop, Search Type, Search Arrest Reason, State, VehicleType, Year, Make, Model, Color, Violation Type, Charge, Article, Contributed To Accident, Race, Gender, Driver City, Driver State, DL State, Arrest Type, Geolocation, District Number]
# Index: []

# %%
# Col 10-18
for i in df.iloc[:,9:20].columns:
    print(i,":","\n",df[i].unique())
# Out:
# Accident :
#  ['No' 'Yes']
# Belts :
#  ['No' 'Yes']
# Personal Injury :
#  ['No' 'Yes']
# Property Damage :
#  ['No' 'Yes']
# Fatal :
#  ['No' 'Yes']
# Commercial License :
#  ['No' 'Yes']
# HAZMAT :
#  ['No' 'Yes']
# Commercial Vehicle :
#  ['No' 'Yes']
# Alcohol :
#  ['No' 'Yes']
# Work Zone :
#  ['No' 'Yes']
# Search Conducted :
#  ['No' nan 'Yes']

# %%
# Col 10-19
for i in df.iloc[:,9:19].columns:
    df[i]=df[i].replace({"Yes":True,"No":False})
    df[i].fillna(False)
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_11384\2070707560.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[i]=df[i].replace({"Yes":True,"No":False})

# %%
# Col 10-19
df.iloc[:,9:19].sum()
# Out:
# Accident              56478
# Belts                 64306
# Personal Injury       25109
# Property Damage       45141
# Fatal                   567
# Commercial License    57777
# HAZMAT                  153
# Commercial Vehicle     6606
# Alcohol                2615
# Work Zone               448
# dtype: int64

# %%
# Col 20
df.iloc[:,19]=df.iloc[:,19].fillna("No")

# %%
# Col 21
df["Search Disposition"]=df["Search Disposition"].str.lower()
df["Search Disposition"]=df["Search Disposition"].fillna("Not Applicable")

# %%
# Col 21
df["Search Disposition"].unique()
# Out:
# array(['Not Applicable', 'nothing', 'contraband only', 'property only',
#        'contraband and property', 'dui', 'marijuana'], dtype=object)

# %%
# Col 22
df["Search Outcome"].unique()
# Out:
# array(['Citation', nan, 'Arrest', 'Warning', 'SERO', 'Recovered Evidence'],
#       dtype=object)

# %%
# Col 22
(df["Search Outcome"]=="").sum()
# Out:
# np.int64(0)

# %%
# Col 22
df["Search Outcome"].isna().sum()
# Out:
# np.int64(804561)

# %%
# Col 25
df["Search Type"].unique()
df["Search Type"]=df["Search Type"].fillna("Not Applicable")
df["Search Type"].unique()
# Out:
# array(['Not Applicable', 'Both', 'Person', 'Property',
#        'Search Incidental', 'car', 'PC'], dtype=object)

# %%
# Col 27
print(df["State"].unique())
print(df["State"].isna().sum())
# Out:
# ['MD' 'XX' 'VA' 'NY' 'DC' 'WI' 'NC' 'GA' 'MN' 'OH' 'PA' 'IL' 'KY' 'TX'
#  'NM' 'FL' 'DE' 'AR' 'WY' 'NJ' 'WV' 'OR' 'TN' 'CA' 'IA' 'UT' 'IN' 'AZ'
#  'MO' 'MA' 'LA' 'MS' 'ND' 'SC' 'ME' 'US' 'NV' 'MI' 'PE' 'RI' 'AL' 'WA'
#  'AK' 'OK' 'CT' 'ON' 'KS' 'NB' 'NH' 'MT' 'VT' 'CO' 'VI' 'SD' 'ID' 'NU'
#  'HI' 'QC' 'NE' 'MB' 'AB' nan 'PR' 'PQ' 'NF' 'NS' 'MH' 'BC' 'AS' 'GU' 'IT'
#  'YT' 'SK']
# 59

# %%
# Col 28
df["VehicleType"]=df["VehicleType"].str.split(" - ").str.get(1).str.strip()

# %%
# Col 29
df["Year"]=df["Date Of Stop"].dt.year

# %%
# COl 30-32
df["Make"]=df["Make"].str.lower()
df["Make"]=df["Make"].fillna("not applicable")

# %%
pip install fuzzywuzzy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
make_list=["Acura","Alfa Romeo","Aston Martin","Audi","Bentley","BMW",
           "Buick","Cadillac","Chevrolet","Chrysler","Dodge","Fiat",
           "Fisker","Ford","Genesis","GMC","Honda","Hummer","Hyundai",
           "Infiniti","Isuzu","Jaguar","Jeep","Kia","Lamborghini",
           "Land Rover","Lexus","Lincoln","Lucid","Maserati","Mazda",
           "Mercedes-Benz","Mercury","Mini","Mitsubishi","Nissan",
           "Oldsmobile","Plymouth","Polestar","Pontiac","Porsche","Ram",
           "Rivian","Rolls Royce","Saab","Saturn","Scion","Smart","Subaru",
           "Suzuki","Tesla","Toyota","Volkswagen","Volvo","Freightliner","Hino",
           "International","Kenworth","Mack","Peterbilt","Sterling",
           "Thomas Built","Western Star","Aprilia","Bintelli","Can-Am","Ducati",
           "Harley-Davidson","Kawasaki","KTM","Kymco","Piaggio","Triumph",
           "Vespa","Yamaha"]

# %%
pip install rapidfuzz
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from rapidfuzz import process, fuzz
import pandas as pd

make_list_lower = [m.lower() for m in make_list]

def standardize_make(val,og_list):
    val = str(val).lower()
    match = process.extractOne(val,og_list, scorer=fuzz.ratio, score_cutoff=50)
    
    if match:
        return match[0]
    return val

df["Make"] = df["Make"].apply(standardize_make,args=(make_list_lower,))

# %%
def others(row,make_list):
    if row not in make_list and row!="not applicable":
        return("others")
    else:
        return(row)
    
df["Make"]=df["Make"].apply(others,args=(make_list_lower,))
df["Make"].value_counts()
# Out:
# Make
# toyota            369004
# honda             309136
# ford              188395
# nissan            156258
# chevrolet         151531
#                    ...
# not applicable        74
# lucid                 47
# lamborghini           40
# piaggio               40
# rolls royce           29
# Name: count, Length: 77, dtype: int64

# %%
df["Color"]=df["Color"].str.lower()
df["Color"]=df["Color"].fillna("not applicable")

# %%
color_list = [
    "BEIGE", "BLACK", "BLUE", "BRONZE", "BROWN", "CAMOUFLAGE", 
    "CHROME", "COPPER", "CREAM", "DARK BLUE", "GOLD", "GRAY", 
    "GREEN", "LIGHT BLUE", "LIGHT GREEN", "MAROON", "MULTICOLOR", 
    "ORANGE", "PINK", "PURPLE", "RED", "TAN", "WHITE", "YELLOW"
]

# %%
color_list_lower = [m.lower() for m in color_list]
df["Color"]=df["Color"].apply(standardize_make,args=(color_list_lower,))
df["Color"]=df["Color"].apply(others,args=(color_list_lower,))
df["Color"].value_counts()
# Out:
# Color
# black             436741
# others            365410
# white             341530
# gray              252862
# blue              219253
# red               157087
# green              91379
# gold               56015
# tan                35616
# maroon             34111
# not applicable     22265
# beige              20267
# brown               8731
# orange              7336
# yellow              7231
# bronze              4503
# purple              3759
# multicolor          1560
# cream               1115
# copper               590
# pink                 315
# chrome                45
# camouflage            40
# Name: count, dtype: int64

# %%
# Col 33
df["Violation Type"].unique()
df["Violation Type"]=df["Violation Type"].astype("string")
df["Violation Type"].dtypes
# Out:
# string[python]

# %%
# Col 35
print(df["Article"].unique())
df["Article"]=df["Article"].astype("string")
print(df["Article"].dtypes)
# Out:
# ['Transportation Article' nan 'Maryland Rules' '00' 'BR' 'TG' '1A']
# string

# %%
# Col 36
print(df["Contributed To Accident"].unique())
print(df["Contributed To Accident"].dtypes)
# Out:
# [False  True]
# bool

# %%
# Col 37
df["Race"]=df["Race"].astype("string").str.lower()
print(df["Race"].unique())
print(df["Race"].dtypes)
# Out:
# <StringArray>
# ['white', 'hispanic', 'black', 'other', 'asian', 'native american']
# Length: 6, dtype: string
# string

# %%
# Col 38
df["Gender"]=df["Gender"].astype("string")
df["Gender"]=df["Gender"].replace("U","Unknown")
print(df["Gender"].unique())
print(df["Gender"].dtypes)
# Out:
# <StringArray>
# ['M', 'F', 'Unknown']
# Length: 3, dtype: string
# string

# %%
# Col 39
df["Driver City"]=df["Driver City"].str.lower()
df["Driver City"].isna().sum()
# Out:
# np.int64(514)

# %%
# Col 40
print(df["Driver State"].unique())
df["Driver State"]=df["Driver State"].astype("string")
print(df["Driver State"].dtypes)
# Out:
# ['MD' 'FL' 'DC' 'OH' 'VA' 'LA' 'NC' 'NY' 'GA' 'PA' 'TN' 'IN' 'WV' 'DE'
#  'NJ' 'WA' 'TX' 'MA' 'IA' 'SC' 'CT' 'CA' 'MI' 'SD' 'MO' 'NM' 'AL' 'ME'
#  'KY' 'IL' 'RI' 'KS' 'AZ' 'XX' 'MS' 'AK' 'CO' 'ON' 'NE' 'ND' 'OK' 'WY'
#  'NV' 'UT' 'NH' 'WI' 'AR' 'PR' 'OR' 'NB' 'MT' 'MN' 'VT' 'QC' 'VI' 'US'
#  'HI' 'MB' 'BC' 'ID' nan 'AB' 'NF' 'GU' 'SK' 'PQ' 'PE' 'NS' 'IT']
# string

# %%
# Col 41
df["DL State"].str.strip().str.contains("\b[A-Z]{2}\b")
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 2070110    False
# 2070111    False
# 2070112    False
# 2070113    False
# 2070114    False
# Name: DL State, Length: 2067761, dtype: object

# %%
df["DL State"].unique()
# Out:
# array(['MD', 'VA', 'FL', 'DC', 'OH', 'LA', 'NC', 'NY', 'XX', 'ME', 'GA',
#        'KY', 'PA', 'CA', 'IL', 'MA', 'TN', 'SC', 'IN', 'WV', 'NJ', 'WA',
#        'TX', 'US', 'IA', 'WI', 'NV', 'CT', 'MI', 'SD', 'MO', 'NM', 'AL',
#        'PE', 'HI', 'RI', 'DE', 'ND', 'CO', 'KS', 'AZ', 'MS', 'AK', 'ON',
#        'NE', 'OK', 'WY', 'OR', 'UT', 'IT', 'NH', nan, 'NB', 'AB', 'PR',
#        'ID', 'AR', 'MN', 'BC', 'MT', 'MB', 'VT', 'QC', 'VI', 'SK', 'MH',
#        'PQ', 'AS', 'NF', 'GU', 'NS', 'YT', 'NU'], dtype=object)

# %%
# Col 42
df["Arrest Type"]=df["Arrest Type"].str.split(" - ").str.get(1).str.strip()
df["Arrest Type"]=df["Arrest Type"].astype("string")
print(df["Arrest Type"].dtypes)
# Out:
# string

# %%
df["Arrest Type"].isna().sum()
# Out:
# np.int64(0)

# %%
# Col 43
df.drop(columns=["Geolocation"],inplace=True)

# %%
df.columns
# Out:
# Index(['SeqID', 'Date Of Stop', 'Time Of Stop', 'Agency', 'SubAgency',
#        'Description', 'Location', 'Latitude', 'Longitude', 'Accident', 'Belts',
#        'Personal Injury', 'Property Damage', 'Fatal', 'Commercial License',
#        'HAZMAT', 'Commercial Vehicle', 'Alcohol', 'Work Zone',
#        'Search Conducted', 'Search Disposition', 'Search Outcome',
#        'Search Reason', 'Search Reason For Stop', 'Search Type',
#        'Search Arrest Reason', 'State', 'VehicleType', 'Year', 'Make', 'Model',
#        'Color', 'Violation Type', 'Charge', 'Article',
#        'Contributed To Accident', 'Race', 'Gender', 'Driver City',
#        'Driver State', 'DL State', 'Arrest Type', 'District Number'],
#       dtype='object')

# %%
charge_df=df[["SeqID","Date Of Stop","Time Of Stop","Charge","Article","Description","Violation Type"]]
charge_df.head()
charge_df.to_csv("Charge_df.csv")

# %%
pd.set_option('display.max_rows', None)

# %%
for i in df["Driver City"].unique():
    print(i)
# Out:
# gaithersburg
# silver spring
# bethesda
# beltsville
# darnestown
# potomac
# columbia
# hyattsville
# boyds
# leesburg
# montgomery village
# burtonsville
# frederick
# derwood
# cabin john
# washington
# akron
# ellicot city
# germantown
# oakton
# north potomac
# mount airy
# metairie
# baltimore
# laurel
# siler city
# damascus
# middle river
# rockville
# brooklyn
# clarksburg
# bowie
# adelphi
# gaitherburg
# poolesville
# lanham
# glen burnie
# hagerstown
# giathersburg
# kensington
# olney
# fayetteville
# brookeville
# pikesville
# alexandria
# sykesville
# n potomac
# knoxville
# aldie
# douglasville
# adelphui
# fairmount heights
# greenbelt
# new market
# point of rocks
# mclean
# capital heights
# n bethesda
# glenelg
# montpelier
# essex
# falls church
# york
# alexandra
# chesapeake
# cockeysville
# takoma park
# brunswick
# gwynn oak
# wheaton
# bladensburg
# riverdale
# nashville
# dundalk
# fulton
# woodbridge
# spencerville
# manchester
# ellicott city
# ...

# %%
cleaned_df=df.copy()

# %%
cleaned_df.drop(columns=["Charge","Description","Article","Violation Type"],inplace=True)

# %%
cleaned_df.drop_duplicates(inplace=True,ignore_index=True)

# %%
cleaned_df.shape
# Out:
# (1183537, 39)

# %%
cleaned_df["SeqID"].nunique()
# Out:
# 1178080

# %%
df["SeqID"].nunique()
# Out:
# 1178080

# %%
simply=cleaned_df[["Accident","Contributed To Accident"]].copy()

# %%
simply.drop_duplicates(inplace=True)
simply.head()
# Out:
#     Accident  Contributed To Accident
# 0      False                    False
# 10      True                     True

# %%
cleaned_df.drop(columns=["Contributed To Accident"],inplace=True)

# %%
cleaned_df.drop_duplicates(subset=["SeqID"],keep=False,inplace=True)

# %%
cleaned_df["SeqID"].nunique()
# Out:
# 1172711

# %%
cleaned_df.shape
# Out:
# (1172711, 38)

# %%
charge_df=pd.read_csv("Charge_df.csv",index_col=False)

# %%
charge_df.head()
# Out:
#    Unnamed: 0                                 SeqID Date Of Stop Time Of Stop  \
# 0           0  52282e8c-f2e1-4bb5-8509-2d5e4f8da8ca   2023-05-01     23:11:00
# 1           1  b66f253b-af29-4bc4-bb73-93755ca2a779   2023-08-31     16:41:00
# 2           2  b66f253b-af29-4bc4-bb73-93755ca2a779   2023-08-31     16:41:00
# 3           3  b66f253b-af29-4bc4-bb73-93755ca2a779   2023-08-31     16:41:00
# 4           4  b66f253b-af29-4bc4-bb73-93755ca2a779   2023-08-31     16:41:00
#
#        Charge                 Article  \
# 0  13-401(b1)  Transportation Article
# 1  16-101(a1)  Transportation Article
# 2   13-409(b)  Transportation Article
# 3   21-310(a)  Transportation Article
# 4   21-801(b)  Transportation Article
#
#                                          Description Violation Type
# 0    operating unregistered motor vehicle on highway       Citation
# 1  driving to drive motor vehicle on highway with...       Citation
# ...

# %%
charge_df1=pd.merge(charge_df,cleaned_df,how="inner",on="SeqID")[["SeqID","Date Of Stop_x","Time Of Stop_x","Charge","Article","Description","Violation Type"]]

# %%
charge_df1.shape
# Out:
# (2041369, 7)

# %%
charge_df1.to_csv("Charge_df.csv",index=False)

# %%
cleaned_df.shape
# Out:
# (1172711, 38)

# %%
cleaned_df.to_csv("Cleaned_df.csv",index=False)
